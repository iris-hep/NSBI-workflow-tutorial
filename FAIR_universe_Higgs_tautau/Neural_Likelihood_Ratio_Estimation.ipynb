# %% [markdown]
# Train Neural Networks to estimate Likelihood Ratios
# ===
#
# In this notebook we will setup the neural networks that train unbiased and low-variance density ratios to be then used for neural simulation-based inference.

# %%
import os, sys, pathlib, importlib
sys.path.append('../')

# Load the package and modules for training and plotting
import nsbi_common_utils
from nsbi_common_utils import plotting, training, datasets, configuration
from nsbi_common_utils.training import density_ratio_trainer


import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Nadam
import mplhep as hep
import matplotlib.pyplot as plt
import pickle
import yaml
import random

from utils import preselection_using_score, calculate_preselection_observable

from coffea.analysis_tools import PackedSelection

import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

hep.style.use(hep.style.ATLAS)
# Out:
# /home/jsandesara_umass_edu/NSBI-workflow-tutorial/src/nsbi_common_utils/plotting.py:10: FutureWarning: ``set_style`` is deprecated: Naming convention is changing to match mpl. Use ``mplhep.style.use()``.
#   hep.set_style("ATLAS")
# 2025-11-13 13:50:54.677533: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-11-13 13:50:54.697881: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-11-13 13:50:54.703979: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-13 13:50:54.719171: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
importlib.reload(sys.modules['nsbi_common_utils.configuration'])
from nsbi_common_utils import configuration

# Load the config file to get metadata like training features
config = nsbi_common_utils.configuration.ConfigManager(file_path_string = './config.yml')

# %%
# Input features for training
features, features_scaling = config.get_training_features()

# %% [markdown]
# Statistical Model
# -
#
# The statistical model for the analysis can be written as:
#
# $$p(x|\mu, \alpha) = \frac{1}{\nu(\mu, \alpha)} \sum_c f_c(\mu) \cdot \nu_c(\alpha) \cdot p_c\left(x|\alpha\right)$$
#
# where $c$ stands for the various physics channels that contribute to the final state $x$, **$\mu$ is the signal-strength parameter and $\alpha$ is the vector of nuisance parameters associated with the various systematic uncertainties in the model**. Note that we are assuming that the parameter $\mu$-dependence is known analytically, given by $f(\mu)$ and that we have simulation models for each of the channels $p_c(x)$.
#
# Setting up the test
# -
#
# The objective is to build the test statistic for composite hypothesis testing:
#
# $$t_\mu = -2 \cdot \frac{\text{Pois}(\mathcal{N}_\text{evts}|\mu, \hat{\hat{\alpha}})}{\text{Pois}(\mathcal{N}_\text{evts}|\hat{\mu}, \hat{\alpha})} -2 \cdot \sum_i^{\mathcal{N}_\text{evts}} w_i \times \log \frac{p(x_i|\mu, \hat{\hat{\alpha}})}{p(x_i|\hat{\mu}, \hat{\alpha})} + \sum_m^{N_\text{systs}} \alpha_m^2$$
#
# A direct approach would then be to model the probability density $p(x|\mu, \alpha)$. This can be done using generative models like Normalizing Flows.
#
# In the presence of high-dimensional inputs, including discrete inputs like the number of jets, this is a more difficult task than training probability density *ratios*. We rewrite the test statistic to turn this into a density ratio estimation task:
#
# $$t_\mu = -2 \cdot \frac{\text{Pois}(\mathcal{N}_\text{evts}|\mu, \hat{\hat{\alpha}})}{\text{Pois}(\mathcal{N}_\text{evts}|\hat{\mu}, \hat{\alpha})} -2 \cdot \sum_i^{\mathcal{N}_\text{evts}} w_i \times \log \frac{p(x_i|\mu, \hat{\hat{\alpha}})/p_{ref}(x)}{p(x_i|\hat{\mu}, \hat{\alpha})/p_{ref}(x)} + \sum_m^{N_\text{systs}} \alpha_m^2$$
#
#
# Then using the analytical statistical model:
#
# $$\frac{p(x|\mu, \alpha)}{p_{ref}(x)} = \frac{1}{\nu(\mu, \alpha)} \sum_c f_c(\mu) \cdot \nu_c(\alpha) \cdot \frac{p_c\left(x|\alpha\right)}{p_{ref}(x)}$$
#
# Further rewriting of the model, factorizing out the $\alpha$-dependence gives,
#
# $$\frac{p(x|\mu, \alpha)}{p_{ref}(x)} = \frac{1}{\sum_c G_c(\alpha) \cdot f_c(\mu) \cdot \nu_c} \sum_c f_c(\mu) \cdot G_c(\alpha)\cdot \nu_c \cdot g_c(x|\alpha) \cdot \frac{p_c\left(x\right)}{p_{ref}(x)}$$
#
# Factorized approach:
# --
#
# Instead of training NNs parameterized on $\mu$ and $\alpha$, we use analytical parameterizations to simplify the problem to training only parameter-independent density ratios.
#
# Let's set this up for the toy $H\to \tau\tau$ model we are using. **Neglecting the nuisance parameter dependence ($G_c(\alpha) = g_c(x|\alpha) = 1$), the probability model can be written as**
#
# $$\sum_c f_c(\mu) \cdot \nu_c(\mu) \cdot \frac{p_c\left(x\right)}{p_{ref}(x)} = \mu \cdot \nu_{H \to \tau\tau}(\mu) \cdot  \frac{p_{H \to \tau\tau}\left(x\right)}{p_{ref}(x)} + \nu_{t\bar{t}}(\mu) \cdot  \frac{p_{t\bar{t}}\left(x\right)}{p_{ref}(x)} + \nu_{Z \to \tau\tau}(\mu) \cdot  \frac{p_{Z \to \tau\tau}\left(x\right)}{p_{ref}(x)}$$
#
# In the NSBI approach presented in this tutorial, the density ratio estimation as a function of the various nuisance parameters is factorized from the nominal density ratio estimation, and will be done in the  `Systematic_Uncertainty_Estimation.ipynb` notebook.

# %%
importlib.reload(sys.modules['nsbi_common_utils.datasets'])
from nsbi_common_utils import datasets

branches_to_load = features + ['presel_score']

Datasets = nsbi_common_utils.datasets.datasets(config_path = './config.yml',
                                                branches_to_load =  branches_to_load)

# %%
dataset_incl_dict      = Datasets.load_datasets_from_config(load_systematics = False)

dataset_incl_nominal   = dataset_incl_dict["Nominal"].copy()

dataset_SR_nominal     = Datasets.filter_region_dataset(dataset_incl_nominal,
                                                       region = "SR")

# %% [markdown]
# Density ratio training
# ===
#
# Now we train the NNs for $\frac{p_c}{p_{ref}}(x)$ density ratios to build the full model. Our choice of reference hypothesis, motivated by the search-oriented mixture model described above, would be:
#
# $$p_{ref}(x) = p_{H \to \tau\tau}(x) = \frac{1}{\nu_{H \to \tau\tau}} \frac{d\sigma_{H \to \tau\tau}}{dx} $$
#
# gives the POI $\mu-$parameterized model:
#
# $$\sum_c \left[f_c(\mu) \cdot \frac{p_c\left(x\right)}{p_{ref}(x)} \right]= \mu + \frac{p_{t\bar{t}}\left(x\right)}{p_{H \to \tau\tau}(x)} + \frac{p_{Z \to \tau\tau}\left(x\right)}{p_{H \to \tau\tau}(x)}$$
#
# But this has shown to cause numerical issues, since the ratio corresponding to the $\mu$-scaling signal term is exactly 1. In the absence of additional signal production mechansims, we instead use:
#
# $$p_{ref}(x) = \frac{1}{\nu_{H \to \tau\tau} + \nu_{t\bar{t}}} \left[\frac{d\sigma_{H \to \tau\tau}}{dx} + \frac{d\sigma_{t\bar{t}}}{dx} \right]$$
#
# giving a more numerically stable model:
#
# $$\sum_c \left[f_c(\mu) \cdot \frac{p_c\left(x\right)}{p_{ref}(x)} \right]= \mu \cdot \frac{p_{H \to \tau\tau}\left(x\right)}{p_{ref}(x)} + \frac{p_{t\bar{t}}\left(x\right)}{p_{ref}(x)} + \frac{p_{Z \to \tau\tau}\left(x\right)}{p_{ref}(x)}$$
#
# The task of estimating the $\mu$-parameterized density ratio is thus reduced to estimating three $\mu$-independent density ratios $\frac{p_{H \to \tau\tau}}{p_{ref}}(x)$, $\frac{p_{t\bar{t}}}{p_{ref}}(x)$ and $\frac{p_{Z \to \tau\tau}}{p_{ref}}(x)$ mixed together with an analytical parameterization (hence the name mixture model).
#
# **NB**: This is the same as the *morphing-aware* approach of density ratio estimation in MadMiner

# %%
# Define the processes that make up the mixture model formula for density ratio estimation

PATH_TO_SAVED_DATA = './saved_datasets/'
TRAINING_OUTPUT_PATH = f'{PATH_TO_SAVED_DATA}output_training_nominal/'

# Signal processes in the model
basis_processes = config.get_basis_samples()
print(basis_processes)

ref_processes = config.get_reference_samples()
print(ref_processes)
# Out:
# ['htautau', 'ttbar', 'ztautau']
# ['htautau', 'ttbar']

# %%
importlib.reload(sys.modules['nsbi_common_utils.training'])
from nsbi_common_utils.training import density_ratio_trainer

NN_training_mix_model = {}

use_log_loss = False

# DELETE_EXISTING_MODELS = True
DELETE_EXISTING_MODELS = False

path_to_ratios = {}
path_to_figures = {}
path_to_models = {}

for process_type in basis_processes:

    dataset_mix_model = Datasets.prepare_basis_training_dataset(dataset_SR_nominal, [process_type], dataset_SR_nominal, ref_processes)

    # Save paths
    output_name                     = f'{process_type}'
    output_dir                      = f'{TRAINING_OUTPUT_PATH}general_output_{process_type}'
    path_to_ratios[process_type]    = f'{TRAINING_OUTPUT_PATH}output_ratios_{process_type}/'
    path_to_figures[process_type]   = f'{TRAINING_OUTPUT_PATH}output_figures_{process_type}/'
    path_to_models[process_type]    = f'{TRAINING_OUTPUT_PATH}output_model_params_{process_type}/'

    NN_training_mix_model[process_type] = density_ratio_trainer(dataset_mix_model, 
                                                                   dataset_mix_model['weights_normed'].to_numpy(),
                                                                   dataset_mix_model['train_labels'].to_numpy(),
                                                                   features, 
                                                                   features_scaling, 
                                                                   [process_type, 'ref'], 
                                                                    output_dir, output_name, 
                                                                    path_to_figures=path_to_figures[process_type],
                                                                    path_to_ratios=path_to_ratios[process_type], 
                                                                    path_to_models=path_to_models[process_type],
                                                                    use_log_loss = use_log_loss,
                                                                    delete_existing_models = DELETE_EXISTING_MODELS)

    del dataset_mix_model

# %% [markdown]
# Neural Network architecture
# ===
#
# Here we will start with a multi-layer perceptron (simple feed-forward Neural Network with fully-connected layers). This can be supplemented with more complex architectures like transformers.
#
# After detailed tuning during the off-shell Higgs boson analysis effort, we found that a network with very wide layers ($\geq 1000$) and a depth of less than 10 works best - alongside batch size of a few hundreds and a gradually declining learning rate that starts with a value just large enough to not blow up.

# %% [markdown]
# Starting with the training and validation of the various density ratio:
#
# $$\frac{p_{H\to\tau\tau}(x)}{p_\text{ref}(x)}, \frac{p_{t\bar{t}}(x)}{p_\text{ref}(x)}, \frac{p_{Z \to \tau\tau}(x)}{p_\text{ref}(x)}$$

# %%
print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available: 1

# %%
# You can either train your own NNs (in which case set this to False) or you can load the pre-trained NNs. 
# Training NNs without GPUs can be very slow, for the kind of NNs we need for unbiased estimation of density ratios
USE_SAVED_MODELS = True

# Define unique settings for each process type
doCalibration = False
RECALIBRATE = False
num_bins_cal = 500
scaling_type = 'MinMax'
batch_size = 512
validation_split = 0.1
holdout_split = 0.25

num_epochs = 100
callback_patience = 30

num_layers = 4
num_neurons_per_layer = 1000

num_ensemble_members = 15

verbose_level = 1

PLOT_SCALED_FEATURES = False

CALIBRATION_TYPE = "histogram"

training_settings = {

    'htautau': {
        'hidden_layers':        num_layers,
        'neurons':              num_neurons_per_layer,
        'number_of_epochs':     num_epochs,
        'batch_size':           batch_size,
        'learning_rate':        0.1,
        'scalerType':           scaling_type,
        'calibration':          doCalibration,
        'num_bins_cal':         num_bins_cal,
        'callback':             True,
        'callback_patience':    callback_patience,
        'callback_factor':      0.01,
        'validation_split':     validation_split,
        'holdout_split':        holdout_split,
        'verbose':              verbose_level,
        'plot_scaled_features': PLOT_SCALED_FEATURES,
        'load_trained_models':  USE_SAVED_MODELS,
        'recalibrate_output'   : RECALIBRATE,
        'type_of_calibration'  : CALIBRATION_TYPE,
        'num_ensemble_members': num_ensemble_members,
        'summarize_model': True
    },
    
    'ttbar': {
        'hidden_layers':        num_layers,
        'neurons':              num_neurons_per_layer,
        'number_of_epochs':     num_epochs,
        'batch_size':           batch_size,
        'learning_rate':        0.1,
        'scalerType':           scaling_type,
        'calibration':          doCalibration,
        'num_bins_cal':         num_bins_cal,
        'callback':             True,
        'callback_patience':    callback_patience,
        'callback_factor':      0.01,
        'validation_split':     validation_split,
        'holdout_split':        holdout_split,
        'verbose':              verbose_level,
        'plot_scaled_features': PLOT_SCALED_FEATURES,
        'load_trained_models':  USE_SAVED_MODELS,
        'recalibrate_output'   : RECALIBRATE,
        'type_of_calibration'  : CALIBRATION_TYPE,
        'num_ensemble_members': num_ensemble_members,
        'summarize_model': True
    },
    
    'ztautau': {
        'hidden_layers':        num_layers,
        'neurons':              num_neurons_per_layer,
        'number_of_epochs':     num_epochs,
        'batch_size':           batch_size,
        'learning_rate':        0.1,
        'scalerType':           scaling_type,
        'calibration':          doCalibration,
        'num_bins_cal':         num_bins_cal,
        'callback':             True,
        'callback_patience':    callback_patience,
        'callback_factor':      0.01,
        'validation_split':     validation_split,
        'holdout_split':        holdout_split,
        'verbose':              verbose_level,
        'plot_scaled_features': PLOT_SCALED_FEATURES,
        'load_trained_models':  USE_SAVED_MODELS,
        'recalibrate_output'   : RECALIBRATE,
        'type_of_calibration'  : CALIBRATION_TYPE,
        'num_ensemble_members': num_ensemble_members,
        'summarize_model': True
    }
}

# %%
# Train the density ratio NN

for count, process_type in enumerate(basis_processes):
    
    settings = training_settings[process_type]

    NN_training_mix_model[process_type].train_ensemble(**settings)
    NN_training_mix_model[process_type].test_normalization()
# Out:
# 2025-11-13 13:51:17 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_htautau/
# 2025-11-13 13:51:22 | INFO | Training Logs | Loading existing model for ensemble member 1
# 2025-11-13 13:51:23 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_htautau/
# 2025-11-13 13:51:28 | INFO | Training Logs | Loading existing model for ensemble member 2
# 2025-11-13 13:51:29 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_htautau/
# 2025-11-13 13:51:34 | INFO | Training Logs | Loading existing model for ensemble member 3
# 2025-11-13 13:51:35 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_htautau/
# 2025-11-13 13:51:40 | INFO | Training Logs | Loading existing model for ensemble member 4
# 2025-11-13 13:51:41 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_htautau/
# 2025-11-13 13:51:46 | INFO | Training Logs | Loading existing model for ensemble member 5
# 2025-11-13 13:51:47 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_htautau/
# 2025-11-13 13:51:51 | INFO | Training Logs | Loading existing model for ensemble member 6
# 2025-11-13 13:51:53 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_htautau/
# 2025-11-13 13:51:57 | INFO | Training Logs | Loading existing model for ensemble member 7
# 2025-11-13 13:51:59 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_htautau/
# 2025-11-13 13:52:03 | INFO | Training Logs | Loading existing model for ensemble member 8
# 2025-11-13 13:52:05 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_htautau/
# 2025-11-13 13:52:09 | INFO | Training Logs | Loading existing model for ensemble member 9
# 2025-11-13 13:52:11 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_htautau/
# 2025-11-13 13:52:15 | INFO | Training Logs | Loading existing model for ensemble member 10
# 2025-11-13 13:52:17 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_htautau/
# 2025-11-13 13:52:21 | INFO | Training Logs | Loading existing model for ensemble member 11
# 2025-11-13 13:52:23 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_htautau/
# 2025-11-13 13:52:27 | INFO | Training Logs | Loading existing model for ensemble member 12
# 2025-11-13 13:52:29 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_htautau/
# 2025-11-13 13:52:33 | INFO | Training Logs | Loading existing model for ensemble member 13
# 2025-11-13 13:52:35 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_htautau/
# 2025-11-13 13:52:39 | INFO | Training Logs | Loading existing model for ensemble member 14
# 2025-11-13 13:52:41 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_htautau/
# 2025-11-13 13:52:47 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 0 is 1.0012520777659253
#
#
# 2025-11-13 13:52:50 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 1 is 1.0001792988113858
#
#
# 2025-11-13 13:52:52 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 2 is 1.0025290557202775
#
#
# 2025-11-13 13:52:54 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 3 is 0.9995786941367119
#
#
# 2025-11-13 13:52:56 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 4 is 1.0016707331680699
#
#
# 2025-11-13 13:52:58 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 5 is 0.9989890404027068
#
#
# 2025-11-13 13:53:01 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 6 is 1.003039395987775
#
#
# 2025-11-13 13:53:03 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 7 is 0.9999368151876556
#
#
# 2025-11-13 13:53:05 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 8 is 1.0040648586024006
#
#
# 2025-11-13 13:53:07 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 9 is 1.0013823061627218
#
#
# 2025-11-13 13:53:09 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 10 is 1.0013774801397446
#
#
# 2025-11-13 13:53:12 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 11 is 1.0010886892712703
#
#
# 2025-11-13 13:53:14 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 12 is 1.0023429477809058
#
#
# 2025-11-13 13:53:16 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 13 is 1.002659391552258
#
#
# 2025-11-13 13:53:18 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 14 is 1.0033906785701066
#
#
# 2025-11-13 13:53:18 | INFO | Training Logs | The sum of PDFs using the whole ensemble is 1.0015654308839945
#
#
#
# 2025-11-13 13:53:18 | INFO | Training Logs | starting ensemble training
# 2025-11-13 13:53:18 | INFO | Training Logs | Loading existing model for ensemble member 0
# 2025-11-13 13:53:19 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ttbar/
# 2025-11-13 13:53:22 | INFO | Training Logs | Loading existing model for ensemble member 1
# 2025-11-13 13:53:23 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ttbar/
# 2025-11-13 13:53:26 | INFO | Training Logs | Loading existing model for ensemble member 2
# 2025-11-13 13:53:27 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ttbar/
# 2025-11-13 13:53:30 | INFO | Training Logs | Loading existing model for ensemble member 3
# 2025-11-13 13:53:31 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ttbar/
# 2025-11-13 13:53:33 | INFO | Training Logs | Loading existing model for ensemble member 4
# 2025-11-13 13:53:34 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ttbar/
# 2025-11-13 13:53:37 | INFO | Training Logs | Loading existing model for ensemble member 5
# 2025-11-13 13:53:38 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ttbar/
# 2025-11-13 13:53:41 | INFO | Training Logs | Loading existing model for ensemble member 6
# 2025-11-13 13:53:42 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ttbar/
# 2025-11-13 13:53:45 | INFO | Training Logs | Loading existing model for ensemble member 7
# 2025-11-13 13:53:46 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ttbar/
# 2025-11-13 13:53:48 | INFO | Training Logs | Loading existing model for ensemble member 8
# 2025-11-13 13:53:49 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ttbar/
# 2025-11-13 13:53:52 | INFO | Training Logs | Loading existing model for ensemble member 9
# 2025-11-13 13:53:53 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ttbar/
# 2025-11-13 13:53:56 | INFO | Training Logs | Loading existing model for ensemble member 10
# 2025-11-13 13:53:57 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ttbar/
# 2025-11-13 13:54:00 | INFO | Training Logs | Loading existing model for ensemble member 11
# 2025-11-13 13:54:01 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ttbar/
# 2025-11-13 13:54:03 | INFO | Training Logs | Loading existing model for ensemble member 12
# 2025-11-13 13:54:04 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ttbar/
# 2025-11-13 13:54:07 | INFO | Training Logs | Loading existing model for ensemble member 13
# 2025-11-13 13:54:08 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ttbar/
# 2025-11-13 13:54:11 | INFO | Training Logs | Loading existing model for ensemble member 14
# 2025-11-13 13:54:12 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ttbar/
# 2025-11-13 13:54:16 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 0 is 0.999151858533821
#
#
# 2025-11-13 13:54:17 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 1 is 1.001749582517858
#
#
# 2025-11-13 13:54:19 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 2 is 1.003373871076531
#
#
# 2025-11-13 13:54:20 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 3 is 1.0030635184171703
#
#
# 2025-11-13 13:54:22 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 4 is 1.0021202850483317
#
#
# 2025-11-13 13:54:23 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 5 is 1.0024350141353884
#
#
# 2025-11-13 13:54:24 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 6 is 1.0013307243642704
#
#
# 2025-11-13 13:54:26 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 7 is 0.9986230751009317
#
#
# 2025-11-13 13:54:27 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 8 is 1.0058205783346144
#
#
# 2025-11-13 13:54:29 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 9 is 0.9981226685780188
#
#
# 2025-11-13 13:54:30 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 10 is 0.9973430960362192
#
#
# 2025-11-13 13:54:31 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 11 is 0.9980113038261895
#
#
# 2025-11-13 13:54:33 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 12 is 1.0010343562957629
#
#
# 2025-11-13 13:54:34 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 13 is 1.0027890197142406
#
#
# 2025-11-13 13:54:36 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 14 is 1.0013487059099557
#
#
# 2025-11-13 13:54:36 | INFO | Training Logs | The sum of PDFs using the whole ensemble is 1.001087843859287
#
#
#
# 2025-11-13 13:54:36 | INFO | Training Logs | starting ensemble training
# 2025-11-13 13:54:36 | INFO | Training Logs | Loading existing model for ensemble member 0
# 2025-11-13 13:54:37 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ztautau/
# 2025-11-13 13:54:40 | INFO | Training Logs | Loading existing model for ensemble member 1
# 2025-11-13 13:54:41 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ztautau/
# 2025-11-13 13:54:45 | INFO | Training Logs | Loading existing model for ensemble member 2
# 2025-11-13 13:54:46 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ztautau/
# 2025-11-13 13:54:49 | INFO | Training Logs | Loading existing model for ensemble member 3
# 2025-11-13 13:54:50 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ztautau/
# 2025-11-13 13:54:53 | INFO | Training Logs | Loading existing model for ensemble member 4
# 2025-11-13 13:54:55 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ztautau/
# 2025-11-13 13:54:58 | INFO | Training Logs | Loading existing model for ensemble member 5
# 2025-11-13 13:54:59 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ztautau/
# 2025-11-13 13:55:02 | INFO | Training Logs | Loading existing model for ensemble member 6
# 2025-11-13 13:55:03 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ztautau/
# 2025-11-13 13:55:07 | INFO | Training Logs | Loading existing model for ensemble member 7
# 2025-11-13 13:55:08 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ztautau/
# 2025-11-13 13:55:11 | INFO | Training Logs | Loading existing model for ensemble member 8
# 2025-11-13 13:55:12 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ztautau/
# 2025-11-13 13:55:16 | INFO | Training Logs | Loading existing model for ensemble member 9
# 2025-11-13 13:55:17 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ztautau/
# 2025-11-13 13:55:20 | INFO | Training Logs | Loading existing model for ensemble member 10
# 2025-11-13 13:55:21 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ztautau/
# 2025-11-13 13:55:25 | INFO | Training Logs | Loading existing model for ensemble member 11
# 2025-11-13 13:55:26 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ztautau/
# 2025-11-13 13:55:29 | INFO | Training Logs | Loading existing model for ensemble member 12
# 2025-11-13 13:55:30 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ztautau/
# 2025-11-13 13:55:35 | INFO | Training Logs | Sum of weights of class 0: 0.7503590805299792
# 2025-11-13 13:55:35 | INFO | Training Logs | Sum of weights of class 1: 0.7500012204518498
# 2025-11-13 13:55:35 | INFO | Training Logs | Using swish activation function
# /home/jsandesara_umass_edu/NSBI-workflow-tutorial/.pixi/envs/nsbi-env-gpu/lib/python3.12/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-11-13 13:55:35.126212: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9449 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:1a:00.0, compute capability: 7.5
# 2025-11-13 13:55:36 | INFO | Training Logs | Using Callbacks
# Epoch 1/100
# 2025-11-13 13:55:39.012665: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-11-13 13:55:39.181555: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8907
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 22s 7ms/step - binary_accuracy: 0.8671 - loss: 3.4340e-07 - val_binary_accuracy: 0.8733 - val_loss: 3.3107e-07 - learning_rate: 0.1000
# Epoch 2/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8753 - loss: 3.2308e-07 - val_binary_accuracy: 0.8744 - val_loss: 3.2408e-07 - learning_rate: 0.1000
# Epoch 3/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8762 - loss: 3.1893e-07 - val_binary_accuracy: 0.8744 - val_loss: 3.2163e-07 - learning_rate: 0.1000
# Epoch 4/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8774 - loss: 3.1608e-07 - val_binary_accuracy: 0.8768 - val_loss: 3.1868e-07 - learning_rate: 0.1000
# Epoch 5/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8782 - loss: 3.1262e-07 - val_binary_accuracy: 0.8787 - val_loss: 3.1523e-07 - learning_rate: 0.1000
# Epoch 6/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8800 - loss: 3.0923e-07 - val_binary_accuracy: 0.8780 - val_loss: 3.1516e-07 - learning_rate: 0.1000
# Epoch 7/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8810 - loss: 3.0655e-07 - val_binary_accuracy: 0.8804 - val_loss: 3.0925e-07 - learning_rate: 0.1000
# Epoch 8/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8818 - loss: 3.0451e-07 - val_binary_accuracy: 0.8817 - val_loss: 3.0680e-07 - learning_rate: 0.1000
# Epoch 9/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8823 - loss: 3.0311e-07 - val_binary_accuracy: 0.8809 - val_loss: 3.0852e-07 - learning_rate: 0.1000
# Epoch 10/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8828 - loss: 3.0200e-07 - val_binary_accuracy: 0.8826 - val_loss: 3.0566e-07 - learning_rate: 0.1000
# Epoch 11/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8832 - loss: 3.0128e-07 - val_binary_accuracy: 0.8830 - val_loss: 3.0433e-07 - learning_rate: 0.1000
# Epoch 12/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8836 - loss: 3.0038e-07 - val_binary_accuracy: 0.8827 - val_loss: 3.0335e-07 - learning_rate: 0.1000
# Epoch 13/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8839 - loss: 2.9992e-07 - val_binary_accuracy: 0.8835 - val_loss: 3.0379e-07 - learning_rate: 0.1000
# Epoch 14/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8841 - loss: 2.9946e-07 - val_binary_accuracy: 0.8837 - val_loss: 3.0260e-07 - learning_rate: 0.1000
# Epoch 15/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8843 - loss: 2.9889e-07 - val_binary_accuracy: 0.8837 - val_loss: 3.0153e-07 - learning_rate: 0.1000
# Epoch 16/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8847 - loss: 2.9843e-07 - val_binary_accuracy: 0.8843 - val_loss: 3.0134e-07 - learning_rate: 0.1000
# Epoch 17/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8846 - loss: 2.9796e-07 - val_binary_accuracy: 0.8839 - val_loss: 3.0225e-07 - learning_rate: 0.1000
# Epoch 18/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8848 - loss: 2.9748e-07 - val_binary_accuracy: 0.8849 - val_loss: 3.0237e-07 - learning_rate: 0.1000
# Epoch 19/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8850 - loss: 2.9710e-07 - val_binary_accuracy: 0.8844 - val_loss: 3.0084e-07 - learning_rate: 0.1000
# Epoch 20/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8854 - loss: 2.9683e-07 - val_binary_accuracy: 0.8849 - val_loss: 2.9962e-07 - learning_rate: 0.1000
# Epoch 21/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8854 - loss: 2.9634e-07 - val_binary_accuracy: 0.8835 - val_loss: 3.0061e-07 - learning_rate: 0.1000
# Epoch 22/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8857 - loss: 2.9610e-07 - val_binary_accuracy: 0.8847 - val_loss: 2.9890e-07 - learning_rate: 0.1000
# Epoch 23/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8856 - loss: 2.9593e-07 - val_binary_accuracy: 0.8849 - val_loss: 2.9909e-07 - learning_rate: 0.1000
# Epoch 24/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8857 - loss: 2.9545e-07 - val_binary_accuracy: 0.8841 - val_loss: 3.0143e-07 - learning_rate: 0.1000
# Epoch 25/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8857 - loss: 2.9524e-07 - val_binary_accuracy: 0.8849 - val_loss: 3.0003e-07 - learning_rate: 0.1000
# Epoch 26/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8858 - loss: 2.9497e-07 - val_binary_accuracy: 0.8844 - val_loss: 2.9970e-07 - learning_rate: 0.1000
# Epoch 27/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8860 - loss: 2.9488e-07 - val_binary_accuracy: 0.8859 - val_loss: 2.9846e-07 - learning_rate: 0.1000
# Epoch 28/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8862 - loss: 2.9461e-07 - val_binary_accuracy: 0.8857 - val_loss: 2.9921e-07 - learning_rate: 0.1000
# Epoch 29/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8864 - loss: 2.9445e-07 - val_binary_accuracy: 0.8852 - val_loss: 2.9861e-07 - learning_rate: 0.1000
# Epoch 30/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8864 - loss: 2.9406e-07 - val_binary_accuracy: 0.8846 - val_loss: 2.9972e-07 - learning_rate: 0.1000
# Epoch 31/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8862 - loss: 2.9393e-07 - val_binary_accuracy: 0.8853 - val_loss: 2.9902e-07 - learning_rate: 0.1000
# Epoch 32/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8875 - loss: 2.9108e-07 - val_binary_accuracy: 0.8871 - val_loss: 2.9592e-07 - learning_rate: 0.0010
# Epoch 33/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8878 - loss: 2.9025e-07 - val_binary_accuracy: 0.8869 - val_loss: 2.9565e-07 - learning_rate: 0.0010
# Epoch 34/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8879 - loss: 2.9005e-07 - val_binary_accuracy: 0.8867 - val_loss: 2.9551e-07 - learning_rate: 0.0010
# Epoch 35/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8880 - loss: 2.8994e-07 - val_binary_accuracy: 0.8868 - val_loss: 2.9553e-07 - learning_rate: 0.0010
# Epoch 36/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8880 - loss: 2.8986e-07 - val_binary_accuracy: 0.8870 - val_loss: 2.9545e-07 - learning_rate: 0.0010
# Epoch 37/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8880 - loss: 2.8980e-07 - val_binary_accuracy: 0.8869 - val_loss: 2.9542e-07 - learning_rate: 0.0010
# Epoch 38/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8879 - loss: 2.8977e-07 - val_binary_accuracy: 0.8867 - val_loss: 2.9544e-07 - learning_rate: 0.0010
# Epoch 39/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8880 - loss: 2.8974e-07 - val_binary_accuracy: 0.8867 - val_loss: 2.9540e-07 - learning_rate: 0.0010
# Epoch 40/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8880 - loss: 2.8971e-07 - val_binary_accuracy: 0.8870 - val_loss: 2.9538e-07 - learning_rate: 0.0010
# Epoch 41/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8879 - loss: 2.8968e-07 - val_binary_accuracy: 0.8869 - val_loss: 2.9541e-07 - learning_rate: 0.0010
# Epoch 42/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8880 - loss: 2.8966e-07 - val_binary_accuracy: 0.8868 - val_loss: 2.9532e-07 - learning_rate: 0.0010
# Epoch 43/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8879 - loss: 2.8964e-07 - val_binary_accuracy: 0.8867 - val_loss: 2.9535e-07 - learning_rate: 0.0010
# Epoch 44/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8880 - loss: 2.8961e-07 - val_binary_accuracy: 0.8866 - val_loss: 2.9532e-07 - learning_rate: 0.0010
# Epoch 45/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8881 - loss: 2.8961e-07 - val_binary_accuracy: 0.8868 - val_loss: 2.9537e-07 - learning_rate: 0.0010
# Epoch 46/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8879 - loss: 2.8958e-07 - val_binary_accuracy: 0.8867 - val_loss: 2.9533e-07 - learning_rate: 0.0010
# Epoch 47/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8880 - loss: 2.8957e-07 - val_binary_accuracy: 0.8867 - val_loss: 2.9530e-07 - learning_rate: 0.0010
# Epoch 48/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8880 - loss: 2.8955e-07 - val_binary_accuracy: 0.8870 - val_loss: 2.9531e-07 - learning_rate: 0.0010
# Epoch 49/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8881 - loss: 2.8953e-07 - val_binary_accuracy: 0.8868 - val_loss: 2.9532e-07 - learning_rate: 0.0010
# Epoch 50/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8881 - loss: 2.8953e-07 - val_binary_accuracy: 0.8868 - val_loss: 2.9525e-07 - learning_rate: 0.0010
# Epoch 51/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8880 - loss: 2.8951e-07 - val_binary_accuracy: 0.8867 - val_loss: 2.9526e-07 - learning_rate: 0.0010
# Epoch 52/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8881 - loss: 2.8950e-07 - val_binary_accuracy: 0.8866 - val_loss: 2.9530e-07 - learning_rate: 0.0010
# Epoch 53/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8880 - loss: 2.8948e-07 - val_binary_accuracy: 0.8868 - val_loss: 2.9526e-07 - learning_rate: 0.0010
# Epoch 54/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8880 - loss: 2.8948e-07 - val_binary_accuracy: 0.8867 - val_loss: 2.9525e-07 - learning_rate: 0.0010
# Epoch 55/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8881 - loss: 2.8946e-07 - val_binary_accuracy: 0.8867 - val_loss: 2.9526e-07 - learning_rate: 0.0010
# Epoch 56/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8881 - loss: 2.8945e-07 - val_binary_accuracy: 0.8867 - val_loss: 2.9521e-07 - learning_rate: 0.0010
# Epoch 57/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8881 - loss: 2.8944e-07 - val_binary_accuracy: 0.8868 - val_loss: 2.9524e-07 - learning_rate: 0.0010
# Epoch 58/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8881 - loss: 2.8943e-07 - val_binary_accuracy: 0.8866 - val_loss: 2.9524e-07 - learning_rate: 0.0010
# Epoch 59/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8881 - loss: 2.8942e-07 - val_binary_accuracy: 0.8867 - val_loss: 2.9523e-07 - learning_rate: 0.0010
# Epoch 60/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8881 - loss: 2.8940e-07 - val_binary_accuracy: 0.8867 - val_loss: 2.9521e-07 - learning_rate: 0.0010
# Epoch 61/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8882 - loss: 2.8940e-07 - val_binary_accuracy: 0.8867 - val_loss: 2.9517e-07 - learning_rate: 0.0010
# Epoch 62/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8882 - loss: 2.8934e-07 - val_binary_accuracy: 0.8867 - val_loss: 2.9517e-07 - learning_rate: 1.0000e-05
# Epoch 63/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8882 - loss: 2.8934e-07 - val_binary_accuracy: 0.8867 - val_loss: 2.9518e-07 - learning_rate: 1.0000e-05
# Epoch 64/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8882 - loss: 2.8933e-07 - val_binary_accuracy: 0.8867 - val_loss: 2.9518e-07 - learning_rate: 1.0000e-05
# Epoch 65/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8882 - loss: 2.8933e-07 - val_binary_accuracy: 0.8867 - val_loss: 2.9518e-07 - learning_rate: 1.0000e-05
# Epoch 66/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8881 - loss: 2.8933e-07 - val_binary_accuracy: 0.8867 - val_loss: 2.9518e-07 - learning_rate: 1.0000e-05
# Epoch 67/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8881 - loss: 2.8933e-07 - val_binary_accuracy: 0.8867 - val_loss: 2.9518e-07 - learning_rate: 1.0000e-05
# Epoch 68/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8881 - loss: 2.8933e-07 - val_binary_accuracy: 0.8867 - val_loss: 2.9518e-07 - learning_rate: 1.0000e-05
# Epoch 69/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8881 - loss: 2.8933e-07 - val_binary_accuracy: 0.8867 - val_loss: 2.9518e-07 - learning_rate: 1.0000e-05
# Epoch 70/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8881 - loss: 2.8933e-07 - val_binary_accuracy: 0.8867 - val_loss: 2.9518e-07 - learning_rate: 1.0000e-05
# Epoch 71/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8882 - loss: 2.8933e-07 - val_binary_accuracy: 0.8867 - val_loss: 2.9518e-07 - learning_rate: 1.0000e-05
# Epoch 72/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8881 - loss: 2.8932e-07 - val_binary_accuracy: 0.8867 - val_loss: 2.9518e-07 - learning_rate: 1.0000e-05
# Epoch 73/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8882 - loss: 2.8932e-07 - val_binary_accuracy: 0.8867 - val_loss: 2.9519e-07 - learning_rate: 1.0000e-05
# Epoch 74/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8882 - loss: 2.8932e-07 - val_binary_accuracy: 0.8867 - val_loss: 2.9519e-07 - learning_rate: 1.0000e-05
# Epoch 75/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8882 - loss: 2.8932e-07 - val_binary_accuracy: 0.8867 - val_loss: 2.9519e-07 - learning_rate: 1.0000e-05
# Epoch 76/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8882 - loss: 2.8932e-07 - val_binary_accuracy: 0.8867 - val_loss: 2.9519e-07 - learning_rate: 1.0000e-05
# Epoch 77/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8882 - loss: 2.8932e-07 - val_binary_accuracy: 0.8867 - val_loss: 2.9519e-07 - learning_rate: 1.0000e-05
# Epoch 78/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8882 - loss: 2.8932e-07 - val_binary_accuracy: 0.8867 - val_loss: 2.9519e-07 - learning_rate: 1.0000e-05
# Epoch 79/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8882 - loss: 2.8932e-07 - val_binary_accuracy: 0.8867 - val_loss: 2.9519e-07 - learning_rate: 1.0000e-05
# Epoch 80/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8882 - loss: 2.8932e-07 - val_binary_accuracy: 0.8867 - val_loss: 2.9519e-07 - learning_rate: 1.0000e-05
# Epoch 81/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8882 - loss: 2.8932e-07 - val_binary_accuracy: 0.8867 - val_loss: 2.9519e-07 - learning_rate: 1.0000e-05
# Epoch 82/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8882 - loss: 2.8932e-07 - val_binary_accuracy: 0.8867 - val_loss: 2.9519e-07 - learning_rate: 1.0000e-05
# Epoch 83/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8882 - loss: 2.8932e-07 - val_binary_accuracy: 0.8867 - val_loss: 2.9519e-07 - learning_rate: 1.0000e-05
# Epoch 84/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8882 - loss: 2.8932e-07 - val_binary_accuracy: 0.8867 - val_loss: 2.9519e-07 - learning_rate: 1.0000e-05
# Epoch 85/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8882 - loss: 2.8932e-07 - val_binary_accuracy: 0.8867 - val_loss: 2.9519e-07 - learning_rate: 1.0000e-05
# Epoch 86/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8882 - loss: 2.8932e-07 - val_binary_accuracy: 0.8867 - val_loss: 2.9519e-07 - learning_rate: 1.0000e-05
# Epoch 87/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8882 - loss: 2.8932e-07 - val_binary_accuracy: 0.8868 - val_loss: 2.9519e-07 - learning_rate: 1.0000e-05
# Epoch 88/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8881 - loss: 2.8932e-07 - val_binary_accuracy: 0.8868 - val_loss: 2.9519e-07 - learning_rate: 1.0000e-05
# Epoch 89/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8882 - loss: 2.8932e-07 - val_binary_accuracy: 0.8868 - val_loss: 2.9519e-07 - learning_rate: 1.0000e-05
# Epoch 90/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8881 - loss: 2.8932e-07 - val_binary_accuracy: 0.8868 - val_loss: 2.9519e-07 - learning_rate: 1.0000e-05
# Epoch 91/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8882 - loss: 2.8932e-07 - val_binary_accuracy: 0.8868 - val_loss: 2.9520e-07 - learning_rate: 1.0000e-05
# Epoch 92/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8882 - loss: 2.8932e-07 - val_binary_accuracy: 0.8868 - val_loss: 2.9520e-07 - learning_rate: 1.0000e-07
# Epoch 93/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8882 - loss: 2.8932e-07 - val_binary_accuracy: 0.8868 - val_loss: 2.9520e-07 - learning_rate: 1.0000e-07
# Epoch 94/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8882 - loss: 2.8932e-07 - val_binary_accuracy: 0.8868 - val_loss: 2.9520e-07 - learning_rate: 1.0000e-07
# Epoch 95/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8882 - loss: 2.8932e-07 - val_binary_accuracy: 0.8868 - val_loss: 2.9520e-07 - learning_rate: 1.0000e-07
# Epoch 96/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8882 - loss: 2.8932e-07 - val_binary_accuracy: 0.8868 - val_loss: 2.9520e-07 - learning_rate: 1.0000e-07
# Epoch 97/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8882 - loss: 2.8932e-07 - val_binary_accuracy: 0.8868 - val_loss: 2.9520e-07 - learning_rate: 1.0000e-07
# Epoch 98/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8882 - loss: 2.8932e-07 - val_binary_accuracy: 0.8868 - val_loss: 2.9520e-07 - learning_rate: 1.0000e-07
# Epoch 99/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8882 - loss: 2.8932e-07 - val_binary_accuracy: 0.8868 - val_loss: 2.9520e-07 - learning_rate: 1.0000e-07
# Epoch 100/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8882 - loss: 2.8932e-07 - val_binary_accuracy: 0.8868 - val_loss: 2.9520e-07 - learning_rate: 1.0000e-07
# 2025-11-13 14:22:10 | INFO | Training Logs | Finished Training
# 2025-11-13 14:22:11.020047: I tensorflow/core/grappler/clusters/single_machine.cc:361] Starting new session
# 2025-11-13 14:22:11.026379: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9449 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:1a:00.0, compute capability: 7.5
# 2025-11-13 14:22:11.295837: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9449 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:1a:00.0, compute capability: 7.5
# 2025-11-13 14:22:11.320241: I tensorflow/core/grappler/clusters/single_machine.cc:361] Starting new session
# 2025-11-13 14:22:11.326665: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9449 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:1a:00.0, compute capability: 7.5
# 2025-11-13 14:22:17 | INFO | Training Logs | Sum of weights of class 0: 0.7509220174102571
# 2025-11-13 14:22:17 | INFO | Training Logs | Sum of weights of class 1: 0.7500012204518498
# 2025-11-13 14:22:17 | INFO | Training Logs | Using swish activation function
# /home/jsandesara_umass_edu/NSBI-workflow-tutorial/.pixi/envs/nsbi-env-gpu/lib/python3.12/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-11-13 14:22:17 | INFO | Training Logs | Using Callbacks
# Epoch 1/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 21s 7ms/step - binary_accuracy: 0.8674 - loss: 3.4482e-07 - val_binary_accuracy: 0.8755 - val_loss: 3.2822e-07 - learning_rate: 0.1000
# Epoch 2/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8746 - loss: 3.2468e-07 - val_binary_accuracy: 0.8776 - val_loss: 3.2014e-07 - learning_rate: 0.1000
# Epoch 3/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8761 - loss: 3.1951e-07 - val_binary_accuracy: 0.8777 - val_loss: 3.1911e-07 - learning_rate: 0.1000
# Epoch 4/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8774 - loss: 3.1541e-07 - val_binary_accuracy: 0.8798 - val_loss: 3.1434e-07 - learning_rate: 0.1000
# Epoch 5/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8785 - loss: 3.1238e-07 - val_binary_accuracy: 0.8800 - val_loss: 3.1218e-07 - learning_rate: 0.1000
# Epoch 6/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8796 - loss: 3.0961e-07 - val_binary_accuracy: 0.8820 - val_loss: 3.0788e-07 - learning_rate: 0.1000
# Epoch 7/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8806 - loss: 3.0726e-07 - val_binary_accuracy: 0.8824 - val_loss: 3.0574e-07 - learning_rate: 0.1000
# Epoch 8/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8814 - loss: 3.0529e-07 - val_binary_accuracy: 0.8840 - val_loss: 3.0284e-07 - learning_rate: 0.1000
# Epoch 9/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8822 - loss: 3.0328e-07 - val_binary_accuracy: 0.8833 - val_loss: 3.0384e-07 - learning_rate: 0.1000
# Epoch 10/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8826 - loss: 3.0196e-07 - val_binary_accuracy: 0.8838 - val_loss: 3.0613e-07 - learning_rate: 0.1000
# Epoch 11/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8831 - loss: 3.0128e-07 - val_binary_accuracy: 0.8832 - val_loss: 3.0359e-07 - learning_rate: 0.1000
# Epoch 12/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8836 - loss: 3.0042e-07 - val_binary_accuracy: 0.8852 - val_loss: 3.0085e-07 - learning_rate: 0.1000
# Epoch 13/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8836 - loss: 2.9969e-07 - val_binary_accuracy: 0.8848 - val_loss: 3.0003e-07 - learning_rate: 0.1000
# Epoch 14/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8842 - loss: 2.9878e-07 - val_binary_accuracy: 0.8853 - val_loss: 2.9961e-07 - learning_rate: 0.1000
# Epoch 15/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8842 - loss: 2.9839e-07 - val_binary_accuracy: 0.8867 - val_loss: 2.9674e-07 - learning_rate: 0.1000
# Epoch 16/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8846 - loss: 2.9794e-07 - val_binary_accuracy: 0.8860 - val_loss: 2.9730e-07 - learning_rate: 0.1000
# Epoch 17/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8848 - loss: 2.9750e-07 - val_binary_accuracy: 0.8864 - val_loss: 2.9711e-07 - learning_rate: 0.1000
# Epoch 18/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8849 - loss: 2.9690e-07 - val_binary_accuracy: 0.8876 - val_loss: 2.9653e-07 - learning_rate: 0.1000
# Epoch 19/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8852 - loss: 2.9649e-07 - val_binary_accuracy: 0.8870 - val_loss: 2.9624e-07 - learning_rate: 0.1000
# Epoch 20/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8851 - loss: 2.9616e-07 - val_binary_accuracy: 0.8876 - val_loss: 2.9493e-07 - learning_rate: 0.1000
# Epoch 21/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8853 - loss: 2.9585e-07 - val_binary_accuracy: 0.8872 - val_loss: 2.9584e-07 - learning_rate: 0.1000
# Epoch 22/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8856 - loss: 2.9546e-07 - val_binary_accuracy: 0.8877 - val_loss: 2.9729e-07 - learning_rate: 0.1000
# Epoch 23/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8854 - loss: 2.9506e-07 - val_binary_accuracy: 0.8860 - val_loss: 2.9589e-07 - learning_rate: 0.1000
# Epoch 24/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8860 - loss: 2.9487e-07 - val_binary_accuracy: 0.8870 - val_loss: 2.9536e-07 - learning_rate: 0.1000
# Epoch 25/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8860 - loss: 2.9465e-07 - val_binary_accuracy: 0.8876 - val_loss: 2.9657e-07 - learning_rate: 0.1000
# Epoch 26/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8862 - loss: 2.9427e-07 - val_binary_accuracy: 0.8879 - val_loss: 2.9405e-07 - learning_rate: 0.1000
# Epoch 27/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8863 - loss: 2.9398e-07 - val_binary_accuracy: 0.8837 - val_loss: 3.0095e-07 - learning_rate: 0.1000
# Epoch 28/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8863 - loss: 2.9384e-07 - val_binary_accuracy: 0.8881 - val_loss: 2.9406e-07 - learning_rate: 0.1000
# Epoch 29/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8863 - loss: 2.9333e-07 - val_binary_accuracy: 0.8882 - val_loss: 2.9372e-07 - learning_rate: 0.1000
# Epoch 30/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8865 - loss: 2.9331e-07 - val_binary_accuracy: 0.8881 - val_loss: 2.9364e-07 - learning_rate: 0.1000
# Epoch 31/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8868 - loss: 2.9295e-07 - val_binary_accuracy: 0.8876 - val_loss: 2.9329e-07 - learning_rate: 0.1000
# Epoch 32/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8881 - loss: 2.8960e-07 - val_binary_accuracy: 0.8890 - val_loss: 2.9096e-07 - learning_rate: 0.0010
# Epoch 33/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8883 - loss: 2.8894e-07 - val_binary_accuracy: 0.8893 - val_loss: 2.9067e-07 - learning_rate: 0.0010
# Epoch 34/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8883 - loss: 2.8874e-07 - val_binary_accuracy: 0.8891 - val_loss: 2.9054e-07 - learning_rate: 0.0010
# Epoch 35/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8884 - loss: 2.8866e-07 - val_binary_accuracy: 0.8893 - val_loss: 2.9046e-07 - learning_rate: 0.0010
# Epoch 36/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8883 - loss: 2.8859e-07 - val_binary_accuracy: 0.8894 - val_loss: 2.9039e-07 - learning_rate: 0.0010
# Epoch 37/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8883 - loss: 2.8852e-07 - val_binary_accuracy: 0.8894 - val_loss: 2.9032e-07 - learning_rate: 0.0010
# Epoch 38/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8883 - loss: 2.8849e-07 - val_binary_accuracy: 0.8896 - val_loss: 2.9027e-07 - learning_rate: 0.0010
# Epoch 39/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8883 - loss: 2.8847e-07 - val_binary_accuracy: 0.8895 - val_loss: 2.9018e-07 - learning_rate: 0.0010
# Epoch 40/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8883 - loss: 2.8843e-07 - val_binary_accuracy: 0.8896 - val_loss: 2.9021e-07 - learning_rate: 0.0010
# Epoch 41/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8884 - loss: 2.8841e-07 - val_binary_accuracy: 0.8896 - val_loss: 2.9021e-07 - learning_rate: 0.0010
# Epoch 42/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8883 - loss: 2.8838e-07 - val_binary_accuracy: 0.8894 - val_loss: 2.9019e-07 - learning_rate: 0.0010
# Epoch 43/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8884 - loss: 2.8836e-07 - val_binary_accuracy: 0.8895 - val_loss: 2.9009e-07 - learning_rate: 0.0010
# Epoch 44/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8884 - loss: 2.8834e-07 - val_binary_accuracy: 0.8896 - val_loss: 2.9007e-07 - learning_rate: 0.0010
# Epoch 45/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8884 - loss: 2.8832e-07 - val_binary_accuracy: 0.8895 - val_loss: 2.9011e-07 - learning_rate: 0.0010
# Epoch 46/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8884 - loss: 2.8831e-07 - val_binary_accuracy: 0.8896 - val_loss: 2.9005e-07 - learning_rate: 0.0010
# Epoch 47/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8884 - loss: 2.8830e-07 - val_binary_accuracy: 0.8894 - val_loss: 2.9007e-07 - learning_rate: 0.0010
# Epoch 48/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8884 - loss: 2.8827e-07 - val_binary_accuracy: 0.8895 - val_loss: 2.9007e-07 - learning_rate: 0.0010
# Epoch 49/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8884 - loss: 2.8827e-07 - val_binary_accuracy: 0.8894 - val_loss: 2.9004e-07 - learning_rate: 0.0010
# Epoch 50/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8885 - loss: 2.8825e-07 - val_binary_accuracy: 0.8896 - val_loss: 2.9001e-07 - learning_rate: 0.0010
# Epoch 51/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 15s 6ms/step - binary_accuracy: 0.8884 - loss: 2.8823e-07 - val_binary_accuracy: 0.8894 - val_loss: 2.9002e-07 - learning_rate: 0.0010
# Epoch 52/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8885 - loss: 2.8822e-07 - val_binary_accuracy: 0.8896 - val_loss: 2.8999e-07 - learning_rate: 0.0010
# Epoch 53/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8884 - loss: 2.8821e-07 - val_binary_accuracy: 0.8894 - val_loss: 2.8997e-07 - learning_rate: 0.0010
# Epoch 54/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8884 - loss: 2.8820e-07 - val_binary_accuracy: 0.8894 - val_loss: 2.9003e-07 - learning_rate: 0.0010
# Epoch 55/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8886 - loss: 2.8818e-07 - val_binary_accuracy: 0.8893 - val_loss: 2.9009e-07 - learning_rate: 0.0010
# Epoch 56/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8885 - loss: 2.8819e-07 - val_binary_accuracy: 0.8896 - val_loss: 2.8993e-07 - learning_rate: 0.0010
# Epoch 57/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8885 - loss: 2.8816e-07 - val_binary_accuracy: 0.8897 - val_loss: 2.8999e-07 - learning_rate: 0.0010
# Epoch 58/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8885 - loss: 2.8815e-07 - val_binary_accuracy: 0.8896 - val_loss: 2.9001e-07 - learning_rate: 0.0010
# Epoch 59/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8885 - loss: 2.8815e-07 - val_binary_accuracy: 0.8895 - val_loss: 2.9000e-07 - learning_rate: 0.0010
# Epoch 60/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8885 - loss: 2.8814e-07 - val_binary_accuracy: 0.8894 - val_loss: 2.9000e-07 - learning_rate: 0.0010
# Epoch 61/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8886 - loss: 2.8813e-07 - val_binary_accuracy: 0.8895 - val_loss: 2.8998e-07 - learning_rate: 0.0010
# Epoch 62/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8885 - loss: 2.8806e-07 - val_binary_accuracy: 0.8894 - val_loss: 2.8997e-07 - learning_rate: 1.0000e-05
# Epoch 63/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8885 - loss: 2.8806e-07 - val_binary_accuracy: 0.8894 - val_loss: 2.8996e-07 - learning_rate: 1.0000e-05
# Epoch 64/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8885 - loss: 2.8805e-07 - val_binary_accuracy: 0.8894 - val_loss: 2.8996e-07 - learning_rate: 1.0000e-05
# Epoch 65/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8885 - loss: 2.8805e-07 - val_binary_accuracy: 0.8894 - val_loss: 2.8995e-07 - learning_rate: 1.0000e-05
# Epoch 66/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8885 - loss: 2.8805e-07 - val_binary_accuracy: 0.8895 - val_loss: 2.8995e-07 - learning_rate: 1.0000e-05
# Epoch 67/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8885 - loss: 2.8805e-07 - val_binary_accuracy: 0.8894 - val_loss: 2.8995e-07 - learning_rate: 1.0000e-05
# Epoch 68/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8885 - loss: 2.8805e-07 - val_binary_accuracy: 0.8895 - val_loss: 2.8995e-07 - learning_rate: 1.0000e-05
# Epoch 69/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8885 - loss: 2.8805e-07 - val_binary_accuracy: 0.8895 - val_loss: 2.8995e-07 - learning_rate: 1.0000e-05
# Epoch 70/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8885 - loss: 2.8805e-07 - val_binary_accuracy: 0.8895 - val_loss: 2.8994e-07 - learning_rate: 1.0000e-05
# Epoch 71/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8885 - loss: 2.8805e-07 - val_binary_accuracy: 0.8895 - val_loss: 2.8994e-07 - learning_rate: 1.0000e-05
# Epoch 72/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8885 - loss: 2.8805e-07 - val_binary_accuracy: 0.8895 - val_loss: 2.8994e-07 - learning_rate: 1.0000e-05
# Epoch 73/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8885 - loss: 2.8805e-07 - val_binary_accuracy: 0.8895 - val_loss: 2.8994e-07 - learning_rate: 1.0000e-05
# Epoch 74/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8885 - loss: 2.8804e-07 - val_binary_accuracy: 0.8895 - val_loss: 2.8994e-07 - learning_rate: 1.0000e-05
# Epoch 75/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8885 - loss: 2.8804e-07 - val_binary_accuracy: 0.8895 - val_loss: 2.8994e-07 - learning_rate: 1.0000e-05
# Epoch 76/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8885 - loss: 2.8804e-07 - val_binary_accuracy: 0.8895 - val_loss: 2.8994e-07 - learning_rate: 1.0000e-05
# Epoch 77/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8885 - loss: 2.8804e-07 - val_binary_accuracy: 0.8895 - val_loss: 2.8994e-07 - learning_rate: 1.0000e-05
# Epoch 78/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8885 - loss: 2.8804e-07 - val_binary_accuracy: 0.8895 - val_loss: 2.8994e-07 - learning_rate: 1.0000e-05
# Epoch 79/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8885 - loss: 2.8804e-07 - val_binary_accuracy: 0.8895 - val_loss: 2.8994e-07 - learning_rate: 1.0000e-05
# Epoch 80/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8886 - loss: 2.8804e-07 - val_binary_accuracy: 0.8895 - val_loss: 2.8994e-07 - learning_rate: 1.0000e-05
# Epoch 81/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8886 - loss: 2.8804e-07 - val_binary_accuracy: 0.8895 - val_loss: 2.8994e-07 - learning_rate: 1.0000e-05
# Epoch 82/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8885 - loss: 2.8804e-07 - val_binary_accuracy: 0.8895 - val_loss: 2.8994e-07 - learning_rate: 1.0000e-05
# Epoch 83/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8885 - loss: 2.8804e-07 - val_binary_accuracy: 0.8895 - val_loss: 2.8994e-07 - learning_rate: 1.0000e-05
# Epoch 84/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8885 - loss: 2.8804e-07 - val_binary_accuracy: 0.8895 - val_loss: 2.8994e-07 - learning_rate: 1.0000e-05
# Epoch 85/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8886 - loss: 2.8804e-07 - val_binary_accuracy: 0.8895 - val_loss: 2.8994e-07 - learning_rate: 1.0000e-05
# Epoch 86/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8885 - loss: 2.8804e-07 - val_binary_accuracy: 0.8895 - val_loss: 2.8994e-07 - learning_rate: 1.0000e-05
# Epoch 87/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8885 - loss: 2.8804e-07 - val_binary_accuracy: 0.8895 - val_loss: 2.8994e-07 - learning_rate: 1.0000e-05
# Epoch 88/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8885 - loss: 2.8804e-07 - val_binary_accuracy: 0.8895 - val_loss: 2.8994e-07 - learning_rate: 1.0000e-05
# Epoch 89/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8885 - loss: 2.8804e-07 - val_binary_accuracy: 0.8895 - val_loss: 2.8994e-07 - learning_rate: 1.0000e-05
# Epoch 90/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8885 - loss: 2.8804e-07 - val_binary_accuracy: 0.8895 - val_loss: 2.8994e-07 - learning_rate: 1.0000e-05
# Epoch 91/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8885 - loss: 2.8804e-07 - val_binary_accuracy: 0.8894 - val_loss: 2.8994e-07 - learning_rate: 1.0000e-05
# Epoch 92/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8885 - loss: 2.8804e-07 - val_binary_accuracy: 0.8894 - val_loss: 2.8994e-07 - learning_rate: 1.0000e-07
# Epoch 93/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8885 - loss: 2.8804e-07 - val_binary_accuracy: 0.8894 - val_loss: 2.8994e-07 - learning_rate: 1.0000e-07
# Epoch 94/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8885 - loss: 2.8804e-07 - val_binary_accuracy: 0.8894 - val_loss: 2.8994e-07 - learning_rate: 1.0000e-07
# Epoch 95/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8885 - loss: 2.8804e-07 - val_binary_accuracy: 0.8894 - val_loss: 2.8994e-07 - learning_rate: 1.0000e-07
# Epoch 96/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8885 - loss: 2.8804e-07 - val_binary_accuracy: 0.8894 - val_loss: 2.8994e-07 - learning_rate: 1.0000e-07
# Epoch 97/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8885 - loss: 2.8804e-07 - val_binary_accuracy: 0.8894 - val_loss: 2.8994e-07 - learning_rate: 1.0000e-07
# Epoch 98/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8885 - loss: 2.8804e-07 - val_binary_accuracy: 0.8894 - val_loss: 2.8994e-07 - learning_rate: 1.0000e-07
# Epoch 99/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8885 - loss: 2.8804e-07 - val_binary_accuracy: 0.8894 - val_loss: 2.8994e-07 - learning_rate: 1.0000e-07
# Epoch 100/100
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - binary_accuracy: 0.8885 - loss: 2.8804e-07 - val_binary_accuracy: 0.8894 - val_loss: 2.8994e-07 - learning_rate: 1.0000e-07
# 2025-11-13 14:48:53 | INFO | Training Logs | Finished Training
# 2025-11-13 14:48:53.521876: I tensorflow/core/grappler/clusters/single_machine.cc:361] Starting new session
# 2025-11-13 14:48:53.528400: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9449 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:1a:00.0, compute capability: 7.5
# 2025-11-13 14:48:53.717113: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9449 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:1a:00.0, compute capability: 7.5
# 2025-11-13 14:48:53.742774: I tensorflow/core/grappler/clusters/single_machine.cc:361] Starting new session
# 2025-11-13 14:48:53.749163: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9449 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:1a:00.0, compute capability: 7.5
# 2025-11-13 14:48:59 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 0 is 0.9995704082822837
#
#
# 2025-11-13 14:49:01 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 1 is 1.0062397410899835
#
#
# 2025-11-13 14:49:02 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 2 is 1.0035100059448123
#
#
# 2025-11-13 14:49:04 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 3 is 1.001232816692273
#
#
# 2025-11-13 14:49:06 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 4 is 1.0058449102600124
#
#
# 2025-11-13 14:49:07 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 5 is 0.9989713259959282
#
#
# 2025-11-13 14:49:09 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 6 is 1.0015353712292918
#
#
# 2025-11-13 14:49:10 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 7 is 1.0050043954347647
#
#
# 2025-11-13 14:49:12 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 8 is 1.0052064017594475
#
#
# 2025-11-13 14:49:14 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 9 is 1.001614753793294
#
#
# 2025-11-13 14:49:15 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 10 is 1.0015697999581197
#
#
# 2025-11-13 14:49:17 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 11 is 1.0017150034271136
#
#
# 2025-11-13 14:49:18 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 12 is 1.0034379004142753
#
#
# 2025-11-13 14:49:20 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 13 is 0.999868202386144
#
#
# 2025-11-13 14:49:22 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 14 is 1.0041200313747376
#
#
# 2025-11-13 14:49:22 | INFO | Training Logs | The sum of PDFs using the whole ensemble is 1.0026294045361654

# %% [markdown]
# Check for overtraining by comparing the NN output distributions between training and holdout datasets. The holdout dataset is the subset of events not used during training.

# %%
for process_type in basis_processes:
    NN_training_mix_model[process_type].make_overfit_plots()

# %% [markdown]
# Diagnostic Checks
# ===
#
# While traditionally, a NN observable is judged on the basis of its accuracy - for NSBI we are interested in the quality of the density ratios more than the discrimination power. The latter comes from the perfect modelling of the multi-dimensional likelihood ratios.
#
# To ensure correct modelling, we run two main checks on the training:
#
# - **Calibration closure test**
#
#   The NNs are trained using the binary cross-entropy loss, which under ideal conditions leads to the NN converging to the score function:
#
#   $$\hat{s}_\text{pred} = \frac{p_\text{ref}(x)}{p_\text{ref}(x)+p_\text{c}(x)}$$
#
#   that can be converted into the probability ratio we desire (likelihood ratio trick):
#
#   $$\frac{p_\text{c}(x)}{p_\text{ref}(x)} = \frac{\hat{s}_\text{pred}(x)}{1-\hat{s}_\text{pred}(x)}$$
#
#   For the NNs to be well-calibrated, we use the Monte Carlo samples to verify the equality:
#
#
#   $$\left[\frac{p_c(x)}{p_c(x)+p_{ref}(x)}\right]_\text{NN} \sim \left[\frac{\mathcal{N}_c^{I(x|\hat{s}_\text{pred})}}{\mathcal{N}_c^{I(x|\hat{s}_\text{pred})}+\mathcal{N}_\text{ref}^{I(x|\hat{s}_\text{pred})}}\right]_\text{MC}$$
#
#   where we bin the events from $p_c$ and $p_\text{ref}$ MC samples, denoted by $\mathcal{N}_c^{I(x|\hat{s}_\text{pred})}$ and $\mathcal{N}_\text{ref}^{I(x|\hat{s}_\text{pred})}$ respectively where $I(x|\hat{s}_\text{pred})$ returns the index of the $\hat{s}_\text{pred}$ bin in which an event $x$ falls.

# %%
num_bins_cal = 50

for process_type in basis_processes:
    NN_training_mix_model[process_type].make_calib_plots(nbins=num_bins_cal, observable='score')

# %%
num_bins_cal = 50

for process_type in basis_processes:
    NN_training_mix_model[process_type].make_calib_plots(nbins=num_bins_cal, observable='llr')

# %% [markdown]
# ## Density ratio reweighting closure tests
#
#   Despite having a well-calibrated output and thus a robust probabilistic interpretation, the trained density ratios might not capture the full multi-dimensional event information $x$. In other words, the NNs might still be biased estimators of the optimal score function, as defined in the CARL paper (link).
#
#   The next diagnostic involves verifying the following equality using 1D projections of $x$:
#
#   $$\frac{p_c(x)}{p_{ref}(x)} \times p_{ref}(x) \sim p_c(x)$$
#
#   We can do this one-by-one for all the observables used to model the density ratios, and also possibly the observables not used directly in the training but can still be well-estimated due to the NN learning the right physics.

# %%
variables_to_plot=['log_DER_pt_h'] # The 1D variable for reweighting closure
yscale_type='log'
num_bins_plotting=21

for process_type in basis_processes:

    NN_training_mix_model[process_type].make_reweighted_plots(variables_to_plot, yscale_type, num_bins_plotting)

# %%
dataset_combined_SR = Datasets.merge_dataframe_dict_for_training(dataset_SR_nominal, None, 
                                                                samples_to_merge = ["htautau", "ztautau", "ttbar"])

# %%
path_to_saved_ratios = {}

for process_type in basis_processes:
    # Evaluate the density ratios p_c/p_ref for the full dataset and save for the inference step
    path_to_saved_ratios[process_type] = NN_training_mix_model[process_type].evaluate_and_save_ratios(dataset_combined_SR, 
                                                                                                     aggregation_type = 'median_score')
# Out:
# 2025-11-13 14:49:35 | INFO | Training Logs | Evaluating density ratios
# 2025-11-13 14:50:01 | INFO | Training Logs | Evaluating density ratios
# 2025-11-13 14:50:27 | INFO | Training Logs | Evaluating density ratios

# %%
# Density ratio paths to put in the config file
path_to_saved_ratios
# Out:
# {'htautau': './saved_datasets/output_training_nominal/output_ratios_htautau/ratio_htautau.npy',
#  'ttbar': './saved_datasets/output_training_nominal/output_ratios_ttbar/ratio_ttbar.npy',
#  'ztautau': './saved_datasets/output_training_nominal/output_ratios_ztautau/ratio_ztautau.npy'}

# %%
# Optionally save the dataframe in the same order used to evaluate the density ratios for diagnostics

path_to_save = f"{PATH_TO_SAVED_DATA}/dataset_Asimov_SR.root"
nsbi_common_utils.datasets.save_dataframe_as_root(dataset_combined_SR, 
                                                  path_to_save = path_to_save,
                                                  tree_name = "nominal")

# %%
path_to_save
# nsbi_common_utils.datasets.load_dataframe_from_root(path_to_save, tree_name = "nominal")
# Out:
# './saved_datasets//dataset_Asimov_SR.root'

# %%
# Asimov weights correspond to the expected weight vector in the same shape and order as the evaluated density ratios
# This is used in the weighted NLL fits for expected sensitivity and coverage computations

path_to_save = f"{PATH_TO_SAVED_DATA}/asimov_weights.npy"
np.save(f"{path_to_save}", dataset_combined_SR["weights"].to_numpy())

# %%
# Path to put in the config file for inference
path_to_save
# Out:
# './saved_datasets//asimov_weights.npy'

# %% [markdown]
# Systematic Uncertainty Modelling
# ===
#
# So far we have left out the nuisance parameter piece of the parameterized density ratio decomposition shown before:
#
# $$g_c(x|\alpha) = \frac{p_c(x|\alpha)}{p_c(x)}$$
#
# which will be estimated in the `Systematic_Uncertainty_Estimation.ipynb` notebook.

# %% [markdown]
# Training an Ensemble of NNs
# ===
#
# In a realistic analysis, a large ensemble of NNs are trained to estimate density ratios, for *each* of the channels. **This reduces not only the variance but has also been found to reduce biases in the final fits.**
#
# In the off-shell Higgs boson analysis, we used k-fold cross-validation, with k=10, to train an ensemble $N_{ens}\sim 250$ of NNs per density ratio $p_c(x)/p_{ref}(x)$. The density ratios used in the final fit are always evaluated on the holdout dataset and by using each of the folds as holdout once, the entire model for $p_c(x)/p_{ref}(x)$ consists of $N_{ens}\times k \sim 2500$ NNs. Each NN in the ensemble is trained by resampling data without replacement from the k-1 folds used for training.
