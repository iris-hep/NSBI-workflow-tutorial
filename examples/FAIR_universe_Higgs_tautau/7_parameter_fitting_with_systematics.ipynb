# %% [markdown]
# Parameter Fitting
# ===
#
# Once all the training and evaluation steps are complete, and the `config_fit_nsbi.yml` file updated with the paths to the saved density ratios, we can perform the parameter fitting step.
#
# We defined Signal Region (SR) and Control Region (CR) channels in the `config_fit_nsbi.yml` file, using a preselection NN trained in `3_preselection_network.ipynb` that isolates signal-rich phase space for the NSBI analysis, with a background-rich phase space, called the CR, used for detailed validations as well as constraining background parameters. We also isolated a binned SR where the signal cross-section dominated that of the background, for a binned Poisson fit to further boost sensitivity in poorly modeled, but signal-dominant, phase space.
#
# The objective in the NSBI SR is to build the test statistic for frequentist composite hypothesis testing:
#
# $$t_\mu = -2 \cdot \frac{\text{Pois}(\mathcal{N}_\text{evts}|\mu, \hat{\hat{\alpha}})}{\text{Pois}(\mathcal{N}_\text{evts}|\hat{\mu}, \hat{\alpha})} -2 \cdot \sum_i^{\mathcal{N}_\text{evts}} w_i \times \log \frac{p(x_i|\mu, \hat{\hat{\alpha}})}{p(x_i|\hat{\mu}, \hat{\alpha})} + \sum_p^{N_\text{systs}} \hat{\hat{\alpha}}_p^2 - \hat{\alpha}_p^2$$
#
# As mentioned in the previous notebooks, we rewrite the test statistic to turn this into a density ratio estimation task:
#
# $$t_\mu = -2 \cdot \frac{\text{Pois}(\mathcal{N}_\text{evts}|\mu, \hat{\hat{\alpha}})}{\text{Pois}(\mathcal{N}_\text{evts}|\hat{\mu}, \hat{\alpha})} -2 \cdot \sum_i^{\mathcal{N}_\text{evts}} w_i \times \log \frac{p(x_i|\mu, \hat{\hat{\alpha}})/p_{ref}(x)}{p(x_i|\hat{\mu}, \hat{\alpha})/p_{ref}(x)} + \sum_p^{N_\text{systs}} \hat{\hat{\alpha}}_p^2 - \hat{\alpha}_p^2$$
#
#
# ## Building the model
#
# In the `4_neural_likelihood_ratio_estimation.ipynb` and `5_systematic_uncertainty_training.ipynb` notebook, we trained neural networks to estimate the relevant density ratios needed to build our full statistical model. In this notebook, we evaluate density ratios using those trained models for the Asimov dataset.
#
# The full model is written as
#
# $$\frac{p(x|\mu, \alpha)}{p_{ref}(x)} = \frac{1}{\sum_c G_c(\alpha) \cdot f_c(\mu) \cdot \nu_c} \sum_c f_c(\mu) \cdot G_c(\alpha)\cdot \nu_c \cdot g_c(x|\alpha) \cdot \underbrace{\frac{p_c\left(x\right)}{p_{ref}(x)}}_{NN}$$
# where,
# $$g_c(x|\alpha) = \frac{p_c(x|\alpha)}{p_\text{c}(x)} = \prod_p \frac{p_c(x|\alpha_p)}{p_\text{c}(x)}$$
#
# and we used a HistFactory-style interpolation generalized to a per-event formulation:
#
# $$\frac{p_c(x|\alpha_p^{eval})}{p_\text{c}(x)} = \begin{cases}
#     \bigg(\underbrace{\frac{p_c(x|\alpha_p^+)}{p_\text{c}(x)}}_{NN}\bigg)^{\alpha_p^\text{eval}}& \alpha_p^\text{eval}>1\\
#     1+\sum_{n=1}^6c_n\cdot (\alpha_p^\text{eval})^n& -1\leq\alpha_p^\text{eval}\leq 1\\
#     \bigg(\underbrace{\frac{p_c(x|\alpha_p^-)}{p_\text{c}(x)}}_{NN}\bigg)^{-\alpha_p^\text{eval}}& \alpha_p^\text{eval}<-1\\
#     \end{cases}$$
#
#
#  In this notebook, we build a statistical model using these trained density ratios that are evaluated on the Asimov dataset in `6_evaluate_networks.ipynb` notebook.

# %%
import os, sys
import pprint
import argparse
import logging
import warnings
import matplotlib.pyplot as plt
import mplhep as hep
import yaml
import jax

import nsbi_common_utils

jax.config.update("jax_enable_x64", True)

# Set Style
hep.style.use(hep.style.ATLAS)

# %%
def load_config(path):
    with open(path, "r") as f:
        return yaml.safe_load(f)

# %%
config_workflow = load_config("./config.pipeline.yaml")["parameter_fitting"]
    
plots_dir = config_workflow["output"]["plots_dir"]

# %%
print("Starting Inference")
print(f"Configurations: Histogram fit = {config_workflow['configs']['histogram']}, NSBI fit = {config_workflow['configs']['nsbi']}")
# Out:
# Starting Inference
# Configurations: Histogram fit = ./config_fit_histogram.yml, NSBI fit = ./config_fit_nsbi.yml

# %%
measurement = config_workflow["measurement"]
print(f"Performing a fit for the measurement {measurement} defined in the fit configuration file")

scan_param = config_workflow["scan"]["parameter"]
scan_range = tuple(config_workflow["scan"]["range"])
scan_steps = config_workflow["scan"]["steps"]
# Out:
# Performing a fit for the measurement higgs_tautau_signal_strength defined in the fit configuration file

# %% [markdown]
# Building a Workspace
# --
#
# Now it is time to write the statistical model into a serialized specification file, referred to as a `workspace` in `pyhf` and `HistFactory` jargon. It can be built from the config file using the `nsbi_common_utils.workspace_builder` class, but also can be provided standalone, following the specific schema defined here.

# %%
hist_config_path = config_workflow["configs"]["histogram"]
ws_hist = nsbi_common_utils.workspace_builder.WorkspaceBuilder(config_path=hist_config_path).build()

# %%
nsbi_config_path = config_workflow["configs"]["nsbi"]
ws_nsbi = nsbi_common_utils.workspace_builder.WorkspaceBuilder(config_path=nsbi_config_path).build()

# %% [markdown]
# The Model
# -
#
# Now lets take a look at how this workspace looks like. It is almost identical to the `pyhf` workspace schema, except it allows for analysis regions with NSBI-type fits.

# %%
print(f"The NSBI fit workspace is \n\n")
pprint.pprint(ws_nsbi)
# Out:
# The NSBI fit workspace is
#
#
# {'channels': [{'name': 'CR',
#                'samples': [{'data': [439.3475, 58366.332, 618334.25],
#                             'modifiers': [{'data': None,
#                                            'name': 'mu_ztautau',
#                                            'type': 'normfactor'},
#                                           {'data': {'hi_data': [0.99929816,
#                                                                 0.9955836,
#                                                                 0.99918866],
#                                                     'lo_data': [0.9992982,
#                                                                 1.0047278,
#                                                                 1.000756]},
#                                            'name': 'JES',
#                                            'type': 'normplusshape'},
#                                           {'data': {'hi_data': [0.99649125,
#                                                                 0.99631304,
#                                                                 0.9975482],
#                                                     'lo_data': [1.0042106,
#                                                                 1.0038878,
#                                                                 1.0025287]},
#                                            'name': 'TES',
#                                            'type': 'normplusshape'}],
#                             'name': 'ztautau'},
#                            {'data': [15465.637, 15453.461, 6895.1445],
#                             'modifiers': [{'data': None,
#                                            'name': 'mu_ttbar',
#                                            'type': 'normfactor'},
#                                           {'data': {'hi_data': [1.000641,
#                                                                 1.0000337,
#                                                                 0.99852705],
#                                                     'lo_data': [0.99940044,
#                                                                 1.0000066,
#                                                                 1.0013245]},
#                                            'name': 'JES',
#                                            'type': 'normplusshape'},
#                                           {'data': {'hi_data': [0.9995797,
#                                                                 1.0007243,
#                                                                 0.99994534],
#                                                     'lo_data': [1.0004485,
#                                                                 0.9992642,
#                                                                 1.000062]},
#                                            'name': 'TES',
#                                            'type': 'normplusshape'}],
#                             'name': 'ttbar'},
#                            {'data': [4.2756114, 18.306545, 142.43988],
#                             'modifiers': [{'data': None,
#                                            'name': 'mu_htautau',
#                                            'type': 'normfactor'},
#                                           {'data': {'hi_data': [0.99962664,
#                                                                 0.99891216,
#                                                                 0.99832374],
#                                                     'lo_data': [1.0005252,
#                                                                 1.0004914,
#                                                                 1.0017744]},
#                                            'name': 'JES',
#                                            'type': 'normplusshape'},
#                                           {'data': {'hi_data': [0.99956006,
#                                                                 0.9991963,
#                                                                 0.9958936],
#                                                     'lo_data': [1.0003713,
#                                                                 1.0007504,
#                                                                 1.0042955]},
#                                            'name': 'TES',
#                                            'type': 'normplusshape'}],
#                             'name': 'htautau'}],
#                'type': 'binned'},
#               {'name': 'SR_binned',
#                'samples': [{'data': [7.091219],
#                             'modifiers': [{'data': None,
#                                            'name': 'mu_ztautau',
#                                            'type': 'normfactor'},
#                                           {'data': {'hi_data': [1.0],
#                                                     'lo_data': [1.0434783]},
#                                            'name': 'JES',
#                                            'type': 'normplusshape'},
#                                           {'data': {'hi_data': [1.0],
#                                                     'lo_data': [1.0]},
#                                            'name': 'TES',
#                                            'type': 'normplusshape'}],
#                             'name': 'ztautau'},
#                            {'data': [0.08151215],
#                             'modifiers': [{'data': None,
#                                            'name': 'mu_ttbar',
#                                            'type': 'normfactor'},
#                                           {'data': {'hi_data': [1.0],
#                                                     'lo_data': [1.0]},
#                                            'name': 'JES',
#                                            'type': 'normplusshape'},
#                                           {'data': {'hi_data': [1.0],
#                                                     'lo_data': [1.0]},
#                                            'name': 'TES',
#                                            'type': 'normplusshape'}],
#                             'name': 'ttbar'},
#                            {'data': [0.61935186],
#                             'modifiers': [{'data': None,
#                                            'name': 'mu_htautau',
#                                            'type': 'normfactor'},
#                                           {'data': {'hi_data': [1.0267136],
#                                                     'lo_data': [0.98034436]},
#                                            'name': 'JES',
#                                            'type': 'normplusshape'},
#                                           {'data': {'hi_data': [0.99798226],
#                                                     'lo_data': [1.0005016]},
#                                            'name': 'TES',
#                                            'type': 'normplusshape'}],
#                             'name': 'htautau'}],
#                'type': 'binned'},
#               {'name': 'SR',
#                'samples': [{'data': [325424.06],
#                             'modifiers': [{'data': None,
#                                            'name': 'mu_ztautau',
#                                            'type': 'normfactor'},
#                                           {'data': {'hi_data': [1.0023319],
#                                                     'hi_ratio': '/home/chakkappai/Work/saved_datasets/output_training_systematics/output_ratios_ztautau_JES_Up/ratio_ztautau.npy',
#                                                     'lo_data': [0.9977203],
#                                                     'lo_ratio': '/home/chakkappai/Work/saved_datasets/output_training_systematics/output_ratios_ztautau_JES_Dn/ratio_ztautau.npy'},
#                                            'name': 'JES',
#                                            'type': 'normplusshape'},
#                                           {'data': {'hi_data': [1.0053204],
#                                                     'hi_ratio': '/home/chakkappai/Work/saved_datasets/output_training_systematics/output_ratios_ztautau_TES_Up/ratio_ztautau.npy',
#                                                     'lo_data': [0.99449813],
#                                                     'lo_ratio': '/home/chakkappai/Work/saved_datasets/output_training_systematics/output_ratios_ztautau_TES_Dn/ratio_ztautau.npy'},
#                                            'name': 'TES',
#                                            'type': 'normplusshape'}],
#                             'name': 'ztautau'},
#                            {'data': [5188.826],
#                             'modifiers': [{'data': None,
#                                            'name': 'mu_ttbar',
#                                            'type': 'normfactor'},
#                                           {'data': {'hi_data': [0.99953467],
#                                                     'hi_ratio': '/home/chakkappai/Work/saved_datasets/output_training_systematics/output_ratios_ttbar_JES_Up/ratio_ttbar.npy',
#                                                     'lo_data': [1.000466],
#                                                     'lo_ratio': '/home/chakkappai/Work/saved_datasets/output_training_systematics/output_ratios_ttbar_JES_Dn/ratio_ttbar.npy'},
#                                            'name': 'JES',
#                                            'type': 'normplusshape'},
#                                           {'data': {'hi_data': [0.9992404],
#                                                     'hi_ratio': '/home/chakkappai/Work/saved_datasets/output_training_systematics/output_ratios_ttbar_TES_Up/ratio_ttbar.npy',
#                                                     'lo_data': [1.0007304],
#                                                     'lo_ratio': '/home/chakkappai/Work/saved_datasets/output_training_systematics/output_ratios_ttbar_TES_Dn/ratio_ttbar.npy'},
#                                            'name': 'TES',
#                                            'type': 'normplusshape'}],
#                             'name': 'ttbar'},
#                            {'data': [844.62604],
#                             'modifiers': [{'data': None,
#                                            'name': 'mu_htautau',
#                                            'type': 'normfactor'},
#                                           {'data': {'hi_data': [1.0002185],
#                                                     'hi_ratio': '/home/chakkappai/Work/saved_datasets/output_training_systematics/output_ratios_htautau_JES_Up/ratio_htautau.npy',
#                                                     'lo_data': [0.9997636],
#                                                     'lo_ratio': '/home/chakkappai/Work/saved_datasets/output_training_systematics/output_ratios_htautau_JES_Dn/ratio_htautau.npy'},
#                                            'name': 'JES',
#                                            'type': 'normplusshape'},
#                                           {'data': {'hi_data': [1.0007136],
#                                                     'hi_ratio': '/home/chakkappai/Work/saved_datasets/output_training_systematics/output_ratios_htautau_TES_Up/ratio_htautau.npy',
#                                                     'lo_data': [0.99925625],
#                                                     'lo_ratio': '/home/chakkappai/Work/saved_datasets/output_training_systematics/output_ratios_htautau_TES_Dn/ratio_htautau.npy'},
#                                            'name': 'TES',
#                                            'type': 'normplusshape'}],
#                             'name': 'htautau'}],
#                'type': 'unbinned'}],
#  'measurements': [{'config': {'parameters': [{'bounds': [[0, 10]],
#                                               'inits': [1],
#                                               'name': 'mu_htautau'},
#                                              {'bounds': [[0, 10]],
#                                               'inits': [1],
#                                               'name': 'mu_ztautau'},
#                                              {'bounds': [[0, 10]],
#                                               'inits': [1],
#                                               'name': 'mu_ttbar'},
#                                              {'inits': [0], 'name': 'JES'},
#                                              {'inits': [0], 'name': 'TES'}],
#                               'poi': 'mu_htautau'},
#                    'name': 'higgs_tautau_signal_strength'}],
#  'observations': [{'data': [15909.259, 73838.086, 625372.6], 'name': 'CR'},
#                   {'data': [7.7919517], 'name': 'SR_binned'},
#                   {'data': [331457.22],
#                    'name': 'SR',
#                    'ratios': {'htautau': '/home/chakkappai/Work/saved_datasets/output_training_nominal/output_ratios_htautau/ratio_htautau.npy',
#                               'ttbar': '/home/chakkappai/Work/saved_datasets/output_training_nominal/output_ratios_ttbar/ratio_ttbar.npy',
#                               'ztautau': '/home/chakkappai/Work/saved_datasets/output_training_nominal/output_ratios_ztautau/ratio_ztautau.npy'},
#                    'weights': '/home/chakkappai/Work/saved_datasets/asimov_weights.npy'}],
#  'version': '1.0.0'}

# %% [markdown]
# The `nsbi_common_utils.models.sbi_parametric_model` can take as input this serialized workspace and build a likelihood model in JAX, with just-in-time (JIT) compilation.

# %%
# model.Model returns the negative log-likelihood 
model_hist = nsbi_common_utils.models.sbi_parametric_model(workspace=ws_hist, 
                                                            measurement_to_fit=measurement)
        
model_nsbi = nsbi_common_utils.models.sbi_parametric_model(workspace=ws_nsbi, 
                                                            measurement_to_fit=measurement)
# Out:
# Loaded ratio data for sample 'ztautau' in channel 'SR': shape (4140344,)
# Loaded ratio data for sample 'ttbar' in channel 'SR': shape (4140344,)
# Loaded ratio data for sample 'htautau' in channel 'SR': shape (4140344,)

# %%
list_params, init_values = model_hist.get_model_parameters()
num_unconstrained = model_hist.num_unconstrained_param

# %% [markdown]
# Having processed all the inputs needed, we pass the likelihood model `nsbi_common_utils.models.sbi_parametric_model` that builds
#
# $$\text{NLL} = -2 \cdot \log \text{Pois}(\mathcal{N}_\text{evts}|\mu, \alpha) - 2\log \frac{p(x|\mu, \alpha)}{p_{ref}(x)} + \sum_p^{N_\text{systs}} \alpha_p^2 $$
#
# with
#
# $$\frac{p(x|\mu, \alpha)}{p_{ref}(x)} = \frac{1}{\sum_c G_c(\alpha) \cdot f_c(\mu) \cdot \nu_c} \sum_c f_c(\mu) \cdot G_c(\alpha) \cdot \nu_c \cdot g_c(x|\alpha) \cdot \frac{p_c\left(x\right)}{p_{ref}(x)}$$
#
# to the `inference` class of `nsbi_common_utils/inference.py` for fitting. The fitting step uses `iminuit` to minimize the NLL and build the profile negative log-likelihood test statistic:
#
# $$t_\mu = -2 \cdot \frac{\text{Pois}(\mathcal{N}_\text{evts}|\mu, \hat{\hat{\alpha}})}{\text{Pois}(\mathcal{N}_\text{evts}|\hat{\mu}, \hat{\alpha})} -2 \cdot \sum_i^{\mathcal{N}_\text{evts}} w_i \times \log \frac{p(x_i|\mu, \hat{\hat{\alpha}})/p_{ref}(x)}{p(x_i|\hat{\mu}, \hat{\alpha})/p_{ref}(x)} + \sum_p^{N_\text{systs}} \hat{\hat{\alpha}}_p^2 - \hat{\alpha}_p^2$$

# %%
inf_hist = nsbi_common_utils.inference.inference(
            model_nll=model_hist.model,
            initial_values=init_values,
            list_parameters=list_params,
            num_unconstrained_params=num_unconstrained,
            model_grad=model_hist.model_grad
        )

inf_nsbi = nsbi_common_utils.inference.inference(
            model_nll=model_nsbi.model,
            initial_values=init_values,
            list_parameters=list_params,
            num_unconstrained_params=num_unconstrained,
            model_grad=model_nsbi.model_grad
        )

# %%
freeze_params = config_workflow.get("freeze_params", [])
print(f"Frozen parameters: {freeze_params}")
# Out:
# Frozen parameters: []

# %%
print("\n" + "="*40)
print(" NSBI FIT RESULTS ")
print("="*40 + "\n")
inf_nsbi.perform_fit(freeze_params=freeze_params)
# Out:
# ========================================
#  NSBI FIT RESULTS
# ========================================
#
# fit:
#  ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = -2.642e+07                 │        Nfcn = 130, Ngrad = 2         │
# │ EDM = 8.95e-05 (Goal: 0.0002)    │           time = 72.9 sec            │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │         Covariance accurate          │
# └──────────────────────────────────┴──────────────────────────────────────┘
# ┌───┬────────────┬───────────┬───────────┬────────────┬────────────┬─────────┬─────────┬───────┐
# │   │ Name       │   Value   │ Hesse Err │ Minos Err- │ Minos Err+ │ Limit-  │ Limit+  │ Fixed │
# ├───┼────────────┼───────────┼───────────┼────────────┼────────────┼─────────┼─────────┼───────┤
# │ 0 │ mu_htautau │   1.10    │   0.28    │            │            │         │         │       │
# │ 1 │ mu_ttbar   │  0.9999   │  0.0010   │            │            │         │         │       │
# │ 2 │ mu_ztautau │   0.997   │   0.007   │            │            │         │         │       │
# │ 3 │ JES        │   -0.3    │    0.4    │            │            │         │         │       │
# │ 4 │ TES        │   0.04    │   0.13    │            │            │         │         │       │
# └───┴────────────┴───────────┴───────────┴────────────┴────────────┴─────────┴─────────┴───────┘
# ┌────────────┬────────────────────────────────────────────────────────┐
# │            │ mu_htautau   mu_ttbar mu_ztautau        JES        TES │
# ├────────────┼────────────────────────────────────────────────────────┤
# │ mu_htautau │     0.0773   -62.6e-6   -0.33e-3      -0.03     -0.004 │
# │   mu_ttbar │   -62.6e-6    1.1e-06    -0.9e-6    21.7e-6     2.1e-6 │
# │ mu_ztautau │   -0.33e-3    -0.9e-6   5.15e-05    0.31e-3    0.05e-3 │
# │        JES │      -0.03    21.7e-6    0.31e-3      0.159     -0.012 │
# │        TES │     -0.004     2.1e-6    0.05e-3     -0.012     0.0178 │
# └────────────┴────────────────────────────────────────────────────────┘

# %%
print("\n" + "="*40)
print(" HISTOGRAM FIT RESULTS ")
print("="*40 + "\n")
inf_hist.perform_fit(freeze_params=freeze_params)
# Out:
# ========================================
#  HISTOGRAM FIT RESULTS
# ========================================
#
# fit:
#  ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = -2.38e+07                  │        Nfcn = 156, Ngrad = 1         │
# │ EDM = 3.24e-08 (Goal: 0.0002)    │            time = 0.5 sec            │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │         Covariance accurate          │
# └──────────────────────────────────┴──────────────────────────────────────┘
# ┌───┬────────────┬───────────┬───────────┬────────────┬────────────┬─────────┬─────────┬───────┐
# │   │ Name       │   Value   │ Hesse Err │ Minos Err- │ Minos Err+ │ Limit-  │ Limit+  │ Fixed │
# ├───┼────────────┼───────────┼───────────┼────────────┼────────────┼─────────┼─────────┼───────┤
# │ 0 │ mu_htautau │    1.0    │    0.5    │            │            │         │         │       │
# │ 1 │ mu_ttbar   │   1.000   │   0.008   │            │            │         │         │       │
# │ 2 │ mu_ztautau │  1.0000   │  0.0011   │            │            │         │         │       │
# │ 3 │ JES        │   -0.0    │    0.7    │            │            │         │         │       │
# │ 4 │ TES        │    0.0    │    0.4    │            │            │         │         │       │
# └───┴────────────┴───────────┴───────────┴────────────┴────────────┴─────────┴─────────┴───────┘
# ┌────────────┬────────────────────────────────────────────────────────┐
# │            │ mu_htautau   mu_ttbar mu_ztautau        JES        TES │
# ├────────────┼────────────────────────────────────────────────────────┤
# │ mu_htautau │      0.204   -0.25e-3  -193.7e-6      -0.05      -0.06 │
# │   mu_ttbar │   -0.25e-3   5.74e-05    -1.2e-6    0.69e-3   -0.07e-3 │
# │ mu_ztautau │  -193.7e-6    -1.2e-6   1.24e-06    19.9e-6    61.2e-6 │
# │        JES │      -0.05    0.69e-3    19.9e-6      0.528      -0.20 │
# │        TES │      -0.06   -0.07e-3    61.2e-6      -0.20      0.158 │
# └────────────┴────────────────────────────────────────────────────────┘

# %%
scan_points_hist, NLL_value_hist, scan_points_StatOnly_hist, NLL_value_StatOnly_hist = inf_hist.perform_profile_scan(parameter_name = scan_param, 
                             freeze_params = freeze_params, 
                             bound_range = scan_range, 
                             fit_strategy = 0, 
                             doStatOnly = True,
                             size = scan_steps)

# %%
scan_points_nsbi, NLL_value_nsbi, scan_points_StatOnly_nsbi, NLL_value_StatOnly_nsbi = inf_nsbi.perform_profile_scan(parameter_name = scan_param, 
                             freeze_params = freeze_params, 
                             bound_range = scan_range, 
                             fit_strategy = 0, 
                             doStatOnly = True,
                             size = scan_steps)

# %%
parameter_label = r'$\mu_{h\tau\tau}$'
list_scan_points = [scan_points_hist, scan_points_StatOnly_hist, scan_points_nsbi, scan_points_StatOnly_nsbi]
list_nll_values = [NLL_value_hist, NLL_value_StatOnly_hist, NLL_value_nsbi, NLL_value_StatOnly_nsbi]
list_labels = ["Histogram Stat+Syst", "Histogram Stat Only", "NSBI Stat+Syst", "NSBI Stat Only"]
list_linestyles = ["-", "--", "-", "--"]
list_colors = ["blue", "blue", "black", "black"]

nsbi_common_utils.inference.plot_NLL_scans(parameter_label, list_scan_points, list_nll_values, list_labels, list_linestyles, list_colors)

# %% [markdown]
# Optimizing the analysis
# ===
#
# **As we increase the number of parameters, the robustness of the density ratio modelling becomes more important. Building ensembles and optimizing preselections are important. Each of the $O(100)$ nuisance paramters typical in an LHC analysis needs to be checked for bias.**
#
# Things that can be optimized for better convergence:
#
# - Generate more simulated events for better modelling.
# - Tighter preselections - removing more of the background-rich phase space $p_{ref}\sim 0$ that can cause numerical instabilites, removing phase space regions with low Monte Carlo statistics or that are difficult to model, etc.
# - Add more input features for easier signal-background separation.
# - Changing the hyperparameters of the various NNs used in the modelling.
# - Training ensembles of NNs
